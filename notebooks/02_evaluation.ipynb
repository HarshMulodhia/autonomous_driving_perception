# %% [markdown]
# # Evaluation & Analysis
#
# This notebook evaluates trained models:
# - mAP computation and PR curves
# - Confusion matrix visualization
# - Failure mode analysis
# - Model comparison (YOLOv8 vs Faster R-CNN)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.evaluation.metrics import DetectionEvaluator, compute_map
from src.evaluation.visualization import (
    plot_precision_recall_curve,
    plot_confusion_matrix,
    visualize_predictions,
)

# %% [markdown]
# ## Load Model and Evaluate

# %%
# TODO: Load your trained model and run evaluation
# from src.models.faster_rcnn import FasterRCNNDetector
# detector = FasterRCNNDetector(num_classes=9)
# detector.load_checkpoint("outputs/faster_rcnn_kitti/best_model.pth")
