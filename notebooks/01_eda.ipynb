# %% [markdown]
# # Dataset Exploration (EDA)
#
# This notebook explores the KITTI and BDD100K datasets:
# - Class distribution analysis
# - Bounding box size statistics
# - Sample image visualization
# - Data augmentation preview

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.datasets.kitti import KITTIDataset, KITTI_CLASS_NAMES
from src.datasets.bdd100k import BDD100KDataset, BDD100K_CLASS_NAMES

# %% [markdown]
# ## KITTI Dataset
# Load and explore the KITTI object detection dataset.

# %%
# TODO: Set your KITTI data root
# kitti_root = "data/kitti"
# dataset = KITTIDataset(kitti_root, split="train")
# print(f"Training images: {len(dataset)}")
